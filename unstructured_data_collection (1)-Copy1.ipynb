# %%
import requests
from bs4 import BeautifulSoup


def get_soup(url):

    header = {
        "User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_13_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/63.0.3239.108 Safari/537.36Name"
    }

    content = requests.get(url , headers = header ).text

    soup = BeautifulSoup(content, "html.parser")
    
    return soup

searchlisting_url = "https://en.jobs.sanofi.com/search-jobs/Singapore?orgIds=20873&alp=1880251&alt=2"

listingsoup = get_soup(searchlisting_url)

# %%
jobpostings= listingsoup.find("ul", {"class": "unstyled-list job-list"})

url_prefix = "https://en.jobs.sanofi.com/"
url_list=[]
for posting in jobpostings.find_all('a', href=True):
    url = url_prefix+posting['href']
    url_list.append(url)
    
url_list
# Out:
# ['https://en.jobs.sanofi.com//job/singapore/clinical-science-associate/20873/10763644',
#  'https://en.jobs.sanofi.com//job/singapore/asia-medical-operations-lead-gem/20873/10469849',
#  'https://en.jobs.sanofi.com//job/singapore/pmo-asia-multi-channel-engagement/20873/10459585',
#  'https://en.jobs.sanofi.com//job/singapore/regional-medical-expert-influenza-asia-and-and-jpac/20873/9623477',
#  'https://en.jobs.sanofi.com//job/singapore/chemical-technician/20873/8947399',
#  'https://en.jobs.sanofi.com//job/singapore/head-epidemiology-and-health-economics-asia-jpac/20873/8328301',
#  'https://en.jobs.sanofi.com//job/singapore/talent-acquisition-marketing-manager-asia-and-jpac/20873/8033145',
#  'https://en.jobs.sanofi.com//job/singapore/regional-head-of-marketing-vaccines-asia-and-jpac/20873/7132131',
#  'https://en.jobs.sanofi.com//job/singapore/regional-digital-and-multi-channel-marketing-manager/20873/6213223',
#  'https://en.jobs.sanofi.com//job/singapore/regional-marketing-manager-meningitis-and-new-technologies/20873/11031098']

# %%
jobinfo=[]

for url in url_list:
    soup = get_soup(url)
    postInfo = {}
    postInfo["role"] = soup.find("title").text
    postInfo["datePosted"] = soup.find('span',{'class':"job-date job-info icon-time with-text"}).text
    postInfo["contractType"] = soup.find('span',{'class':"icon-contract with-text"}).text
    postInfo["jobID"] = soup.find("span", {'class':"job-id job-info icon-job-id with-text"}).text
    postInfo["jobLocation"] = soup.find("span",{'class':"job-location job-info white-text"}).text.strip()
    desc = soup.find('div',{'class':"ats-description"})
    
    sections = [sectionName.text.replace(":","") for sectionName in desc.find_all('b')]
    sectionInfo = desc.find_all('ul')
    for var,info in zip(sections,sectionInfo):
        postInfo[var] = [listitem.text.strip() for listitem in info.find_all('li')]
    
    jobinfo.append(postInfo)

# %%
jobinfo
# Out:
# [{'About Us': ['Responsible for executing with rare disease business strategy and delivering business goals by working closely with the multi-stake holder groups to drive high awareness of rare diseases amongst HCP, patient advocacy groups and other appropriate stake holders, including fund managers, philanthropic organizations, etc, leading to higher testing, diagnosis, increased access to treatment and better patient outcomes.',
#    'Responsible for overall sales performance as allocated.\xa0 To develop key sales opportunities, build a community of key HCP managing rare disease.\xa0 To manage and monitor patient cases by working with the ASM, marketing and medical team in both pre and post-sales activities.'],
#   'Essential Skills and Experience': ['Sales experience in dealing with niche biopharmaceutical market preferred',
#    'Track record in organizing medical meetings, CME, engaging key stakeholders in complex clinical environments e.g. mid and senior level healthcare professionals, key accounts and the medical community',
#    'Track record in influencing the stakeholder decision-making process and creating value in a network with multiple influential-decision makers',
#    'Experience with market access will be an added advantage'],
#   'Person Profile': ['Bachelor Degree in Science, Marketing or equivalent Education',
#    'Valid Class 3/3A driving license'],
#   'Priorities': ['At least 3 years sales or marketing experience in pharmaceutical or healthcare industry',
#    'Strong interpersonal and customer relationship-building skills',
#    'Demonstrated proactiveness in initiating and accomplishing tasks in a focused and disciplined approach'],
#   'Purpose of Role\xa0 ': ['To drive high awareness of disease areas through education programs amongst HCP, patient advocacy groups, allied HCP, and other multi-stake holders groups',
#    'To facilitate and increase testing, diagnosis by educating the need for early diagnosis through appropriate diagnostic tests and subsequent treatment with Sanofi Genzyme products for better patient outcomes.',
#    'To develop and maintain strong positive relationship with healthcare professionals (HCP), patient advocacy groups, alternative funding source owners; working closely with the various stakeholder groups to support patients in gaining access to treatment',
#    'Working closely with the HCPs / Patient Groups / Medical Social Workers / Nurse Counsellors in gaining access to funding sources (including alternative funding) \xa0for diagnosed patients',
#    'Working closely with HCPs (including infusion nurses, hospital pharmacies, etc) and individual hospitals to ensure availability of stocks at all times through monthly monitoring of stock levels, monitoring of diagnostic tests performed by HCPs, monitoring of patient cases and infusion sessions, ordering and liaison with respective distributors, internal supply chain team.',
#    'Gather market intelligence and reporting of competitors’ strategies and activities in the field',
#    'Adherence to code of ethics specified by Sanofi'],
#   'contractType': 'Full time',
#   'datePosted': ' 02/01/2019',
#   'jobID': ' R2492720',
#   'jobLocation': 'Singapore',
#   'role': 'Clinical Science Associate at Sanofi Global (English)'},
#  {'Experience & Skills': ['Manage the annual medical affairs budget for the region and support in generating monthly finance trackers and spending pattern report with the help of Finance team.',
#    'Liaise with region medical head and the finance partner in reallocation of budgets and resources as per emerging business needs.',
#    'Coordinate with global operations team regarding alignment with global budgetary spends and project priorities.',
#    'Monitor regional budget spending pattern and flag up issues to region head as required.'],
#   'Overview': ['Support region head with budgeting and resource allocation for medical affairs across the region.',
#    'Generate and provide accurate and timely performance metrics report for the medical affairs function across Asia.',
#    'Work closely cross functionally with finance, legal, compliance and commercial on various organizational initiatives.',
#    'Manage capability building and skill enhancement programs for the region.',
#    'Manage systems and processes providing work infrastructure to the MSL team across the region.',
#    'Work closely with the region medical head in generating annual budgets and medical affairs spending report.',
#    'Represent the region at global level for operational topics and projects.',
#    'Support region head on information collection and liaison work with the country medical directors.',
#    'Working with internal & external stakeholders for creating and implementing project plans for related medical events.'],
#   'Responsibilities': ['Internal – Global / Asia Medical Team, Regional Functional Teams such as Procurement, Finance, Legal, Compliance, Regulatory etc',
#    'External – Doctors, patient advocacy group, vendors, etc.',
#    'Asia, General Medicines and Emerging Markets'],
#   'contractType': 'Full time',
#   'datePosted': ' 01/08/2019',
#   'jobID': ' R2486999',
#   'jobLocation': 'Singapore',
#   'role': 'Asia Medical Operations Lead, GEM at Sanofi Global (English)'},
#  {'Act as PMO MCE ': ['A minimum of 5-8 year experience in \xa0commercial roles',
#    'At least 4 years solid and rounded digital/MCM expertise within from other industries or from pharma with a focus on creating great customer experiences',
#    'Innovation mindset and experience of applying innovation processes to develop digital products and services with a potential to disrupt the market',
#    'Strong analytical capability to understand the customer and sound business & commercial knowledge to understand the impact',
#    'Ability to think and act strategically combined with an ability to translate plans into operational reality',
#    'Understanding of the key drivers in brand and customer facing activities',
#    'Strong track record of working collaboratively across functions and markets in a high matrix working environment',
#    'Organizational, cultural and interpersonal sensitivity',
#    'Experience working with agencies/vendors & strong team management skills',
#    'Proven managerial and leadership skills, especially strong influencing ability',
#    'Start-up or digital agency experience is desirable'],
#   'Create Culture of Innovation and Continuous Improvement ': ['Strategically lead and execute on digital/MCE programs',
#    'Strong relationship management capabilities; ability to influence others without authority',
#    'Strong communication and influencing skills',
#    'Role modelling, visibility, upholding values, adhering to standards'],
#   'Digital Innovation ': ['Strategy Execution to Maximize Revenues Action oriented to drive plan implementationStrong business acumenHighly analytical, always seeking to understand impact of strategies and activitiesThorough understanding of revenue drivers for brands across countries and how customer facing digital can help achieve these goals',
#    'Action oriented to drive plan implementation',
#    'Strong business acumen',
#    'Highly analytical, always seeking to understand impact of strategies and activities',
#    'Thorough understanding of revenue drivers for brands across countries and how customer facing digital can help achieve these goals'],
#   'Education Qualification': ['Multi-Channel Engagement and Digital competenciesDigital competencies including; digital strategy and integrated planning, content marketing, customer insight and analytics, automation and personalization (CRM), email, search, paid media and programmatic media, customer experience and user experience.',
#    'Digital competencies including; digital strategy and integrated planning, content marketing, customer insight and analytics, automation and personalization (CRM), email, search, paid media and programmatic media, customer experience and user experience.'],
#   'Experience & Knowledge': ['Digital competencies including; digital strategy and integrated planning, content marketing, customer insight and analytics, automation and personalization (CRM), email, search, paid media and programmatic media, customer experience and user experience.'],
#   'Financial Planning': ['Meet Commitments to Patients, Customers & StakeholdersBroad expertise across brand/technology/customers/stakeholdersAbility to facilitate stakeholder & customer commitments and act on customer insightsAbility to synthesize country digital customer insights',
#    'Broad expertise across brand/technology/customers/stakeholders',
#    'Ability to facilitate stakeholder & customer commitments and act on customer insights',
#    'Ability to synthesize country digital customer insights'],
#   'Key Duties and Responsibilities\xa0\xa0\xa0\xa0\xa0\xa0 ': ['Bachelor degree in a related field, eg Marketing, Business, Computer Science, Engineering'],
#   'Leadership': ['LeadershipStrategically lead and execute on digital/MCE programsStrong relationship management capabilities; ability to influence others without authorityStrong communication and influencing skillsRole modelling, visibility, upholding values, adhering to standards',
#    'Strategically lead and execute on digital/MCE programs',
#    'Strong relationship management capabilities; ability to influence others without authority',
#    'Strong communication and influencing skills',
#    'Role modelling, visibility, upholding values, adhering to standards',
#    'Create Culture of Innovation and Continuous Improvement Change leadership: ability to deal with ambiguity and adapt to new modes of operatingDigital Innovation leadershipWillingness to challenge the status quo',
#    'Change leadership: ability to deal with ambiguity and adapt to new modes of operating',
#    'Digital Innovation leadership',
#    'Willingness to challenge the status quo'],
#   'Meet Commitments to Patients, Customers & Stakeholders': ['Change leadership: ability to deal with ambiguity and adapt to new modes of operating',
#    'Digital Innovation leadership',
#    'Willingness to challenge the status quo'],
#   'Multi-Channel Engagement and Digital competencies': ['Understanding and application of innovation tools and processes to bring digital solutions to life (eg design thinking)',
#    'Ability to work with internal and external stakeholders/startups/agencies to leverage and scale to Sanofi solutions'],
#   'PMO, Asia Multi-Channel Engagement ': ['Expedite adaptation of MCE/Digital applied knowledge (such as Search, Web Marketing, Mobile App dev, Social Media, online advertising/Media advertising, content marketing, automation and personalization) and to achieve business and financial results.',
#    'Ensure clarity and consistency across the business with respect to channel definitions and the application of digital marketing within an MCE approach',
#    'Instill a definition of Customer Experience/ Customer Centricity into our processes – should be intrinsic to our activities and processes',
#    'Alignment across the organization from global, regional to local and define clear areas of accountability',
#    'Ensure relevant metrics are in place to monitor success (at least monthly) and business impact of Digital/MCE programs, including ROI where appropriate across the Region and report monthly to the Asia LT',
#    'Develop and execute',
#    'Facilitate sharing of content, services & best practice across in-market MCE Leads, Therapeutic Area teams and brands',
#    'Work in close collaboration with enabling and platform functions seamlessly execute digital programs to time, budget and within compliance',
#    'Work with transversal team to develop a MCE Roadmap and execute accordingly',
#    'Measuring ROI: Work with internal stakeholders and external experts to connect the right data and metrics to our objectives to assess how our MCE campaigns and efforts are making an impact.',
#    'Alignment across Teams',
#    'Be the central point for MCE program ensuring execution to the MCE roadmap and plans and ensure timely delivery to budget',
#    'Ensure a “One Sanofi” approach with other BUs and lead the needs for the GEM business to drive an outcome that is right for the customer'],
#   'Skills & Core Competencies': ['Digital Innovation Understanding and application of innovation tools and processes to bring digital solutions to life (eg design thinking)Ability to work with internal and external stakeholders/startups/agencies to leverage and scale to Sanofi solutions',
#    'Understanding and application of innovation tools and processes to bring digital solutions to life (eg design thinking)',
#    'Ability to work with internal and external stakeholders/startups/agencies to leverage and scale to Sanofi solutions'],
#   'Strategy Execution to Maximize Revenues ': ['Action oriented to drive plan implementation',
#    'Strong business acumen',
#    'Highly analytical, always seeking to understand impact of strategies and activities',
#    'Thorough understanding of revenue drivers for brands across countries and how customer facing digital can help achieve these goals'],
#   'contractType': 'Full time',
#   'datePosted': ' 01/08/2019',
#   'jobID': ' R2484967',
#   'jobLocation': 'Singapore',
#   'role': 'PMO, Asia Multi-Channel Engagement at Sanofi Global (English)'},
#  {'Desirable Qualifications': ['Lead the development of strategy, experience, and knowledge of the local Medics working on the respective franchise, through regular communication and exchanges',
#    'Provide and contribute to training activities',
#    'Ensure efficiency, consistency and long-term continuity of the knowledge within the region'],
#   'Essential Skills and Experience': ['Lead to identify and consolidate the required medical information and activities at the regional level to develop a robust and comprehensive strategy aligned with regional/local objectives and priorities for the franchises',
#    'Develop medical insights to identify unmet market needs and generate recommendations on use of the respective Franchise products for the benefit of patients',
#    'Provide medical & scientific insights to lead the respective Franchise evidence generation/synthesis strategies, taking into account country needs and priorities',
#    'Medical review and approval of promotional and non-promotional materials',
#    'Identifying the required tools and resources needed are planned, developed and available when needed during the implementation and monitoring of the respective franchise strategy in the region.',
#    'Provide expertise in support and collaboration with the country medical teams in the definition, implementation, monitoring and evaluation of their local medical plans to deliver impactful medical insights through their activities and interactions; for the franchise portfolio in the respective countries.',
#    'Support alignment and cross-regional harmonisation of Regional Medical plans with the Global and Local Medical Plans',
#    'Work in collaboration with the different functions (eg public affairs, epidemiology, marketing, health economics, market access, regulatory, pharmacoviligance and project management) both at the region and country levels in the definition and implementation of the regional strategy.',
#    'Ensure regular and constant interaction, communication and collaboration with the different functions working on the products in the respective franchise portfolio and making sure that the regional medical strategy and its implementation are aligned with the global medical strategy.',
#    'Partner with the different functions (eg communications, public policy, marketing, project management, and health economics), providing the medical/scientific input, in the identification and development of key messages to all internal and external stakeholders while identifying the different medical meetings and publications to implement it.',
#    'Identification and management of all external medical and key opinion leaders that will help advocate the public health need of the franchise portfolio, in alignment with the respective franchise SP’s regional medical strategic plans.',
#    'Interact with the different KOLs and other medical specialists, facilitating scientific exchange and ensuring good relationship of Sanofi Pasteur with external stakeholders and institutions.',
#    'Build long-term relationships and partnership with health-care stakeholders, participate to advocacy efforts and develop regional level KOL engagement strategies to support launch and life-cycle activities',
#    'Foster the regional medical community:Lead the development of strategy, experience, and knowledge of the local Medics working on the respective franchise, through regular communication and exchangesProvide and contribute to training activitiesEnsure efficiency, consistency and long-term continuity of the knowledge within the region',
#    'Lead the development of strategy, experience, and knowledge of the local Medics working on the respective franchise, through regular communication and exchanges',
#    'Provide and contribute to training activities',
#    'Ensure efficiency, consistency and long-term continuity of the knowledge within the region',
#    'Be a spokesperson for the company to present and potentially defend the franchise strategy in accordance with the scientific data and evidenceEstablish, develop and maintain contacts with external experts including, international & supranational bodies in the regionDrive scientific planning and content for Sanofi Pasteur activities at congressesExecute scientific meetings with international experts (e.g. advocacy board, clinical research update, masterclass)',
#    'Establish, develop and maintain contacts with external experts including, international & supranational bodies in the region',
#    'Drive scientific planning and content for Sanofi Pasteur activities at congresses',
#    'Execute scientific meetings with international experts (e.g. advocacy board, clinical research update, masterclass)',
#    'Proactively identify & manage medical risks to support regional risk assessment',
#    'Ensure implementation of ethics, transparency, quality and compliance of medical activities within assigned franchise area'],
#   'Key Interfaces': ['Establish, develop and maintain contacts with external experts including, international & supranational bodies in the region',
#    'Drive scientific planning and content for Sanofi Pasteur activities at congresses',
#    'Execute scientific meetings with international experts (e.g. advocacy board, clinical research update, masterclass)'],
#   'contractType': 'Full time',
#   'datePosted': ' 10/11/2018',
#   'jobID': ' R2478311',
#   'jobLocation': 'Singapore',
#   'role': 'Regional Medical Expert - Influenza, Asia and & JPAC at Sanofi Global (English)'},
#  {'JOB PURPOSE': ['Operate the different streams of the plant for their specific processes.'],
#   'KEY ACCOUNTABILITIES': ['Nitec or Diploma in Chemical related courses',
#    'Should have good understanding of safe working practices and cGMP required of a fine chemical plant.',
#    'Able to work three rotating shifts, morning, afternoon and night (8 hour shifts)',
#    'Resourceful, conscientious, dedicated and a good team player.',
#    'Adequate formal and on-the-job training on the chemical processes will be given.'],
#   'REPORTING RELATIONSHIP': ['Comply with HSE and quality policies and defined procedures. Bring out unsafe conditions and acts / procedures for correction.',
#    'Record all operational and analytical data on the appropriate documents and inform the Shift Supervisor of any process abnormalities.',
#    'Maintain product separation and accurate labelling of all documents, bags and vessels at all times.',
#    'Carry out routine checks and scheduled cleaning procedures.',
#    'Collect raw materials, observe clean areas procedures, monitor raw materials stock and notify Shift Supervisor for any abnormalities.',
#    'Notify Shift Supervisor of requirements for maintenance.\xa0 Prepare equipment before maintenance work e.g. depressurizing, cleaning of lines and equipment, de-energizing etc.',
#    "At the Shift Supervisor's request, to carry out on-the-job training of other Chemical Technicians, incorporating cGMP and safety procedures.",
#    'To observe cGMP and Health & Safety rules and regulations at work at all times in accordance with Company set standards.',
#    'To be aware of the potentially hazardous nature of the chemicals in the area and must take the appropriate precautions when using them.',
#    'To operate ancillary facilities e.g. Bio-plant, tank farms, etc.'],
#   'contractType': 'Full time',
#   'datePosted': ' 08/10/2018',
#   'jobID': ' R2471961',
#   'jobLocation': 'Singapore',
#   'role': 'Chemical Technician at Sanofi Global (English)'},
#  {'Job Purpose': ['Develop the region’s evidence generation plan in close collaboration with global partners and regional/country stakeholders (Market Access, Medical Affairs, Policy and Commercial Operations). Reach consensus on the final plan across stakeholders. – 20%',
#    'Lead the execution of the regional epidemiology and health economic evidence generation plan and maintain high scientific excellence. This involves managing vendors and external/internal research collaborators. Publish articles and communicate in scientific congresses – 30%',
#    'Support the use of epidemiological and economic evidence to inform decision-making internally, at Sanofi Pasteur,\xa0 and externally by our customers, recommending bodies and public health -20%',
#    'Develop a network of academic and public health partners that can guide the company’s research agenda, support research execution and thus maximize the company’s ability to generate impactful evidence – 20%',
#    'Develop individuals reporting to role both as solid and dotted lines – 10%'],
#   'Responsibilities': ['MSc or PhD in Epidemiology/Mathematics /Economics or focused on quantitative analysis\xa0 (candidates with a primary Medical or Pharmacy degree will be given special consideration)',
#    'At least 10 years of research experience',
#    'Scientific excellence with exceptional written and oral communication skills',
#    'Expertise in developing epidemiological and economics research studies',
#    'Previous experience working on vaccines or infectious diseases is an advantage',
#    'Strong thinking coupled with \xa0business and public health acumen',
#    'Ability to develop, motivate and lead people',
#    'High level of self-awareness\xa0 and ability to collaborate cross-functionally',
#    'Fluent in English and a comm'],
#   'contractType': 'Full time',
#   'datePosted': ' 06/08/2018',
#   'jobID': ' R2462075',
#   'jobLocation': 'Singapore',
#   'role': 'Head, Epidemiology and Health Economics, Asia JPAC at Sanofi Global (English)'},
#  {'Job overview': ['Lead the implementation of TA Marketing initiatives in Asia',
#    'Define and build regional and local Employer Brand strategies, based on Global Guidelines.',
#    'Defines targeted Employer Value Proposition for specific BUs/BFs/job families in countries.',
#    'Leads go to market strategies in countries (digital, video, accolades, job boards etc) to directly engage with targeted candidate segments.',
#    'Constantly monitors & improves candidate and hiring manager experience.',
#    'Manages the content alignment to Global Guidelines for corporate career sites (both internal and external).',
#    'Manages relations with regional and local TA media agencies.',
#    'Ensures alignment with Local Communications teams.',
#    'Surveys new media technologies trends & innovations to upgrade regional and local plans.',
#    'Develops KPIs, conversion rates, behavior and satisfaction metrics.',
#    'Ensures best practice sharing.'],
#   'Responsibilities': ["Bachelor's Degree in Marketing, Communications, Public Relations or related field.",
#    'Additional related Masters qualification of add advantage',
#    '5 years marketing experience with strong digital culture, ideally in FMCG/consumer, e-commerce or media agency.',
#    'Experience in digital media planning and execution',
#    'High influencing and communication skills',
#    'Innovative mindset with good influencing and communication skills',
#    'Solution oriented attitude with the right balance of innovation and “pragmatic creativity”.',
#    'Collaborative, customer focus and engaging',
#    'Management of remote and multicultural teams and matrix resources.',
#    'HR/Talent Acquisition experience is off add advantage'],
#   'contractType': 'Full time',
#   'datePosted': ' 05/08/2018',
#   'jobID': ' R2455428',
#   'jobLocation': 'Singapore',
#   'role': 'Talent Acquisition Marketing Manager - Asia & JPAC at Sanofi Global (English)'},
#  {'COMMERCIAL EXCELLENCE': ['Bachelor’s degree qualification with Post Grad in Marketing as an added advantage',
#    'Minimum 10 years’ experience in marketing with proven people management experience',
#    'Regional /Global \xa0and /or vaccine market experience is highly desirable and off advantage',
#    'Excellent communication skills and fluency in English with other local languages being a plus',
#    'Strong analytical/financial/business skills with strong customer focus and orientation',
#    'Knowledge with Marketing Effectiveness tools',
#    'Experience in Portfolio Management with exposure to both public and private market',
#    'P&L; understanding – OPEX and A&P; Management',
#    'Cross-Functional Projects, Cross-fertilization skills',
#    'Expert communication skills to lead, influence and impact business strategy and decisions',
#    'Demonstrated and dynamic leadership within large multifunctional teams',
#    'Creative and Strategic Thinking, critical to anticipating changes in the environment, planning and solution finding',
#    'People development and focus to build competencies and capabilities of each individual in the team',
#    'Drive and ability to build a results-oriented organization.'],
#   'PRODUCT LAUNCH & OPERATİONAL MARKETING ACTIVITIES': ['Regional Execution Plan',
#    'Delivering expertise and training to guide and build capabilities and competencies in the countries'],
#   'REGION MARKETING STRATEGY & STRATEGIC PLANNING': ['Country Strategic Planning exercise',
#    'Effective Brand Plans within each country',
#    'Budget & 3 year Financial Forecast exercise'],
#   'Responsibilities': ['Define the regional marketing strategy, in alignment with franchise directions, and drive its implementation throughout the entire region, for both Private and Public/Institutional markets.',
#    'Support & monitor Clusters and Countries in the strategy implementation, to accelerate products launches but also product uptakes & market development, in close collaboration with medical regulatory, public affairs & operations teams',
#    'Provide to countries the marketing, sales force & commercial excellence orientations and tools to support & drive business growth for the core vaccines.',
#    'Enhance marketing, business excellence, communication capabilities throughout the region by emphasizing customer focus and achieving best practices sharing and synergies across the region',
#    'Collaborate with the Global functions to create a dynamic exchange and working environment'],
#   'SALES & MARKETING EXCELLENCE': ['All the stages of product Life Cycle Management',
#    'Pre-launch to launch and beyond',
#    'Developing market strategy and expansion for private and public',
#    'Developing new channels and initiatives to grow the business and evolve the business model',
#    'Anticipate changes in the environment and plan accordingly'],
#   'contractType': 'Full time',
#   'datePosted': ' 02/06/2018',
#   'jobID': ' R2442562',
#   'jobLocation': 'Singapore',
#   'role': 'Regional Head of Marketing, Vaccines - ASIA & JPAC at Sanofi Global (English)'},
#  {'Key Interactions': ['Degree in Marketing or related field',
#    'At least 3 years of experience in Digital Marketing, Multichannel marketing & Customer Journey design',
#    'Strong business acumen\xa0 to be able to develop an in-depth understanding of business environment/models and "customers" needs in healthcare and then translate new technologies into business solutions and competitive advantage',
#    'Project leadership, to drive projects to completion with clear milestones and outcomes',
#    'Commercial experience preferable working with Global/Regional/Local Teams and proven experience with ability to drive stakeholder management and influence',
#    'Familiar with transversal collaboration and able to work in a complex matrix organization',
#    'Good written and verbal communication',
#    'EMS certification',
#    'Experienced with Sitecore, Drupal , Adobe Cloud Marketing or any relevant tools',
#    'Proficient in digital advertising tools such as Google AdWords, Facebook Ad Manager, YouTube, TheTradeDesk, DoubleClick.',
#    'Proficient in analytics tools is required such as Google Analytics, WooRank, SimilarWeb and Nugit.'],
#   'Responsibilities': ['Countries GMs, Marketing Director, Marketing teams',
#    'Region: Regional marketing and franchise teams, ITS, Legal, EBI, Medical, Communications, PA',
#    'Global: Global Digital Team, VP of Digital, Innovation teams, Medical, Legal, EBI,'],
#   'contractType': 'Full time',
#   'datePosted': ' 11/08/2017',
#   'jobID': ' R22300',
#   'jobLocation': 'Singapore',
#   'role': 'Regional Digital & Multi-Channel Marketing Manager at Sanofi Global (English)'},
#  {'BUSINESS PROCESSES': ['Plan and implement activities which prepare the ground for a successful launch: product meetings, workshops, market surveys, adequate training, advocate development, campaigns etc.'],
#   'Develop Marketing Excellence': ['Advanced level of written and verbal English communication skills',
#    'High analytical thinking, innovation, creativity and project management skills',
#    'Excellent presentation skills',
#    'Strong interpersonal/ communication skills',
#    'Confident, respect of deadlines and commitment'],
#   'JOB PURPOSE': ['Provide LRP/CSP/ Budget support to the countries in line with Franchises and Region Strategy for countries to drive their 5 and 10 year plans',
#    'Review and challenge LRP/CSP, Marketing plans and Budget exercise',
#    'Identify areas of growths & risks to be discussed during the planning exercises',
#    'Prepare cross-franchise consolidated overviews for the top Management',
#    'Review country yearly REP requests and support in the coordination with other functions request associated with the brand',
#    'Prepare regional Marketing OPEX for the brand and follow up in the implementation of activity & financial allocation'],
#   'KEY RESPONSIBILITIES AND TASKS ': ['Assist in the preparation and review of Country Brand Plans: Brand Plan preparation, Reviews and Workshops, identification of gaps & next steps, follow up in tactical plan implementation and KPI measurements',
#    'Lead the monthly Regional Brand Team with the regional functions in collaboration with Medical, Regulatory, Supply, SFE, Operations',
#    'Lead regional task forces on specific topics as required (evaluations, business case development etc.)',
#    'Counsel and advise country marketing teams on strategy, planning, implementation and execution',
#    'Coordinate & follow up product launches with Marketing community in countries (launch plan review and challenge, sales follow up etc.)Plan and implement activities which prepare the ground for a successful launch: product meetings, workshops, market surveys, adequate training, advocate development, campaigns etc.',
#    'Plan and implement activities which prepare the ground for a successful launch: product meetings, workshops, market surveys, adequate training, advocate development, campaigns etc.',
#    'Manage transversal projects between countries and global functions (health economics, advisory boards, market research, digital, SFE profiling, etc.)',
#    'Actively support new business activity when required (forecasting and modelling)',
#    'Monthly sales follow up, challenges and corrective action plans proposal if needed.',
#    'Coordinate medico-marketing activities between countries, Medical, Franchises and Congress department (Congress participations, Speaker Tours, Train the Trainers…)',
#    'Represent Asia & JPAC and bring regional perspective to New Technologies global platform'],
#   'PRODUCTS': ['Close relationship with Franchises for competitive intelligence, market trends, best practices sharing, as well as with New Technologies platform',
#    'Asia & JPAC Key Contact Point in Men 4TT GBT (for both Marketing and non-marketing topics as the contact point for global teams representing all functions)',
#    'Co-animation of the Marketing community network (VMA, PerSPectives…)',
#    'Organization of marketing and product sessions at regional meetings',
#    'Actively develop the Marketing community'],
#   'Product launches, existing product support and marketing activities': ['University degree, preferably from a scientific/pharmacist background',
#    'Master degree in marketing would be an assetRelated experience:',
#    'Min 5 years of experience in operational marketing in vaccine or pharma business',
#    'Vaccine experience desirable'],
#   'Regional Marketing Manager position under Vaccine Global Business Unit covering Meningitis & New Technologies\xa0': ['To develop and implement Regional Marketing and Product Strategy',
#    'Support and guide the country marketing teams in the implementation and execution',
#    'Ensure the timely launch of products across the region',
#    'Challenge and follow up strategy implementation,',
#    'Contribute to business performance on the short and mid-term',
#    'Ensure best practices sharing, information exchange, synergies with other departments within Sanofi Pasteur',
#    'Develop marketing excellence across the region'],
#   'Strategic planning exercise, LRP, Budget, REP': ['Ensure right product knowledge by all means (F2F training, new e-tool usage etc)',
#    'Develop with Business Excellence specialist the right templates for launch plan, marketing plans and business analysis',
#    'Participate to SFE projects (segmentation and targeting, and messages alignment)',
#    'Support local marketing teams to optimize their cycle meeting management',
#    'Support in Roll Out of new product materials & promotional materials'],
#   'contractType': 'Full time',
#   'datePosted': ' 02/27/2019',
#   'jobID': ' R2494096',
#   'jobLocation': 'Singapore',
#   'role': 'REGIONAL MARKETING MANAGER – MENINGITIS & NEW TECHNOLOGIES at Sanofi Global (English)'}]

# %%
    
# for section in sections:
#     section.find_all('li')

# %%
len(jobinfo['Requirements'])
# Out:
# 10

# %%
len(job_details_urls)
# Out:
# 10

# %%
for details_url in job_details_urls[0:20]:
    #print details_url
    soup = getsoup(details_url[-1])
    
    #get the title
    title_box = soup.find("div", {"class": "title-page"})
    if title_box:
        job_title = title_box.find("h3")
        #print job_title.text
        
    
        #get the company name
        company_name_h4 = title_box.find("h4")
        company_details = company_name_h4.text.split("Posted On :")
        company_name = company_details[0].strip()
        posted_on = company_details[1].strip()
        
        #print (job_title.text, company_name,posted_on)
        
        
        #COMPANY DETAILS
        company_info_ul = soup.find("ul", {"class": "who"})
        
        #if company_info_ul:
            #print company_info_ul.findChild().text
        
        address = ""
        for a in company_info_ul.find_all("a"):
            address = address + a.text.strip() + ","
        address = address[:-1]
        #print address
        
        print (job_title.text, company_name,posted_on,address)
# Out:
# (u'Software Engineer ', u'Streetsine Singapore Pte Ltd', u'12 Jan 2018', u'http://www.srx.com.sg/')
# (u'Software Engineers/ Senior Software Engineers (Digital Initiatives) ', u'SPH Digital', u'12 Jan 2018', u'1000 TOA PAYOH NORTH NEWS CENTRE Singapore 318994,http://www.sphdigital.com')
# (u'Software Engineers - Swiss Medical Devices industrial leader', u'MICHAEL PAGE INTERNATIONAL (SINGAPORE)', u'12 Jan 2018', u'1 RAFFLES PLACE, #09-61 ONE RAFFLES PLACE Singapore 048616,http://www.michaelpage.com.sg,EA Licence No: 98C5473')
# (u'Software Engineer [ C++ / Computer Engineering / Training Provided!]', u'The Supreme HR Advisory Pte Ltd', u'12 Jan 2018', u'http://www.thesupremehr.com,EA Licence No: 14C7279,Personnel Reg. No: R1657954')
# (u'Software Engineer - C#.Net ', u'MICHAEL PAGE INTERNATIONAL (SINGAPORE)', u'11 Jan 2018', u'1 RAFFLES PLACE, #09-61 ONE RAFFLES PLACE Singapore 048616,http://www.michaelpage.com.sg,EA Licence No: 98C5473')
# (u'Software/System Engineer ( (In-house / West / S$3K++) ', u'Hecal Pte Ltd', u'11 Jan 2018', u'http://www.hecal.sg/index.html,EA Licence No: 12C6198,Personnel Reg. No: R1111728')
# (u'Identity and Access Management (IAM) Software Engineer', u'SPH Digital', u'11 Jan 2018', u'1000 TOA PAYOH NORTH NEWS CENTRE Singapore 318994,http://www.sphdigital.com')
# (u'Firmware Engineer [5 Days / Programming / C+ / Embedded Software]', u'The Supreme HR Advisory Pte Ltd', u'11 Jan 2018', u'http://www.thesupremehr.com,EA Licence No: 14C7279,Personnel Reg. No: R1764404')
# (u'On-Site Engineer [5 days / IT Hardware , Software / Web based] URGENT ', u'The Supreme HR Advisory Pte Ltd', u'11 Jan 2018', u'http://www.thesupremehr.com,EA Licence No: 14C7279,Personnel Reg. No: R1764404')
# (u'IT / Desktop Engineer [Work Life Balance / 5 Days / IT Software Support] ', u'The Supreme HR Advisory Pte Ltd', u'11 Jan 2018', u'http://www.thesupremehr.com,EA Licence No: 14C7279,Personnel Reg. No: R1764404')

# %%
print company_info_ul.findChild
# Out:
# <bound method Tag.find of <ul class="list-unstyled who">\n<li style="text-transform: uppercase;"><strong>The Supreme HR Advisory Pte Ltd</strong>\n</li>\n<li><a href="http://www.thesupremehr.com" target="_blank"><i class="fa fa-globe"></i> http://www.thesupremehr.com</a></li>\n<li><a href="#"><i class="fa fa-info"></i> EA Licence No: 14C7279</a></li>\n<li><a href="#"><i class="fa fa-user"></i> Personnel Reg. No: R1764404</a></li>\n</ul>>
