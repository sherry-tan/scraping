# %%
import shutil
import os
import zipfile

#useful tool for extracting information from XML
import re

#to pretty print our xml:
import xml.dom.minidom
path = "/Users/SherryT/Documents/resumes/2018/untitled/"
os.listdir(path)
# Out:
# ['Resume_Jan_2019.docx', 'Resume_Sep_2018.docx', 'sherry-1pg-DA.docx']

# %%
files = [(path+file) for file in os.listdir(path)]
file=files[0]

# %%
import docx

# %%
document = Document(file)

# %%
dir(document)
document.__class__
# Out:
# docx.document.Document

# %%
text = xml.dom.minidom.parseString(document.read('word/document.xml')).toprettyxml(indent='  ')
print(text)
# Out:
# <?xml version="1.0" ?>
# ...
